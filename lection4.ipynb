# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank.csv', sep=',')
df.sample(n=10)
# Out:
#       age          job   marital  education default  balance housing loan  \
# 9361   46  blue-collar  divorced    primary      no      916     yes   no
# 5970   41  blue-collar   married  secondary      no      641     yes   no
# 960    39   technician    single  secondary      no     4646     yes   no
# 7797   30   management    single   tertiary      no      162     yes   no
# 4509   46  blue-collar   married    unknown      no      842     yes   no
# 2604   36  blue-collar    single  secondary      no       40     yes   no
# 1285   30   management    single   tertiary      no     5561     yes   no
# 9404   31       admin.    single  secondary      no      387     yes   no
# 6824   44  blue-collar   married   tertiary      no     1371      no   no
# 7139   42  blue-collar   married    primary      no      170     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 9361   cellular   11   may       472         2     -1         0  unknown
# 5970    unknown   13   may       161         1     -1         0  unknown
# 960    cellular   18   nov       486         1     -1         0  unknown
# 7797    unknown   20   may       186         4     -1         0  unknown
# 4509  telephone    8   may       833         1     -1         0  unknown
# 2604   cellular   27   aug       259         3    475         4  success
# 1285   cellular   27   feb       195         1    100         1  success
# 9404   cellular   13   may       228         2    370         1  failure
# 6824   cellular   13   may       788         3    363         4    other
# 7139    unknown   19   may        51        41     -1         0  unknown
#
#      deposit
# 9361      no
# 5970      no
# 960      yes
# 7797      no
# 4509     yes
# 2604     yes
# 1285     yes
# 9404      no
# 6824      no
# 7139      no

# %%
plt.figure(figsize=(8, 6))
plt.plot([0, 1, 2, 3], [10, 9, 6, 1])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Example')
plt.grid()

# %%
data = df.groupby('month')['job'].agg(count='count').reset_index().sort_values(by='month')
data.head(12)
# Out:
#    month  count
# 0    apr    923
# 1    aug   1519
# 2    dec    110
# 3    feb    776
# 4    jan    344
# 5    jul   1514
# 6    jun   1222
# 7    mar    276
# 8    may   2824
# 9    nov    943
# 10   oct    392
# 11   sep    319

# %%
plt.figure(figsize=(6, 4))

plt.plot(data['month'], data['count'])

plt.title('Динамика охвата рекламных кампаний')
plt.xlabel('Месяц')
plt.ylabel('Кол-во клиентов')
# Out:
# Text(0, 0.5, 'Кол-во клиентов')
